# %% [markdown]
# # Document Type Classification 2조
#
# ### Contents
# - Import Library & Loading Data
# - EDA
# - Data Preprocessing
# - Define Functions
# - Modeling
# - Train Model
# - Result
# - Save File

# %% [markdown]
# ## 1. Import Library

# %%
import os
import time
import random
import timm
import torch
import albumentations as A
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import albumentations as A
import cv2
from albumentations.pytorch import ToTensorV2
from torch.optim import Adam, AdamW
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from augraphy import *
from sklearn.model_selection import KFold
from glob import glob
from matplotlib.gridspec import GridSpec
from timm import create_model

# %% [raw]
# import sys
# !{sys.executable} -m pip install augraphy

# %%
# 랜덤하게 seed 설정
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# %% [raw]
# class ImageDataset(Dataset):
#     def __init__(self, data, path, transform=None):
#         # data가 파일 경로(str)인지 DataFrame인지 확인
#         if isinstance(data, str):  # CSV 파일 경로일 경우
#             self.df = pd.read_csv(data)  # DataFrame으로 유지
#         else:  # DataFrame이 직접 전달된 경우
#             self.df = data  # DataFrame 그대로 유지
#         self.path = path
#         self.transform = transform
#
#     def __len__(self):
#         return len(self.df)
#
#     def __getitem__(self, idx):
#         row = self.df.iloc[idx]
#         name = row['ID']
#         target = row['class_name']
#         image_path = os.path.join(self.path, name)
#
#         # 이미지 로드
#         img = np.array(Image.open(image_path).convert("RGB"))
#
#         # transform 적용
#         if self.transform:
#             img = self.transform(image=img)['image']
#         return img, target

# %% [raw]
# trn_dataset = ImageDataset(
#     "/Users/choesumin/Documents/upstage/data/train.csv",
#     "/Users/choesumin/Documents/upstage/data/train"
# )
#
# tst_dataset = ImageDataset(
#     "/Users/choesumin/Documents/upstage/data/submission.csv",
#     "/Users/choesumin/Documents/upstage/data/test"
# )
#
# print(len(trn_dataset), len(tst_dataset))

# %%
#load data
train_df = pd.read_csv("/Users/choesumin/Documents/upstage/data/train.csv")
meta_df = pd.read_csv("/Users/choesumin/Documents/upstage/data/meta.csv")
image_dir = "/Users/choesumin/Documents/upstage/data/train"

# %%
#클래스별 이미 파일명과 클래스명 매핑
train_df = train_df.merge(meta_df, on='target')
class_names = train_df['class_name'].unique()

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=SEED, stratify=train_df["class_name"])

# %% [markdown]
# ## 2. EDA

# %% [raw]
# # 클래스별 이미지 확인 [트레이닝 데이터]
# def display_images(images, title):
#     plt.figure(figsize=(50, 200))  # 전체 그림 크기 조정 (figsize를 더 크게)
#     grid = GridSpec(20, 5, wspace=0.1, hspace=0.01)  # 2행 5열의 그리드
#
#     for i, img_path in enumerate(images[:100]):  # 최대 100개 이미지로 제한
#         img = cv2.imread(img_path)
#         img = cv2.resize(img, (300, 300))  # 이미지 크기 조정
#         ax = plt.subplot(grid[i])  # GridSpec을 이용해 서브플롯 설정
#         ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#         ax.axis('off')
#
#     plt.suptitle(title)
#     plt.show()
#
# # 각 클래스별로 10개씩 이미지 출력 (이미지가 매우 크므로 10개로 제한)
# for class_name in class_names:
#     class_images = train_df[train_df['class_name'] == class_name]['ID'].values
#     class_image_paths = [os.path.join(image_dir, img) for img in class_images]
#     display_images(class_image_paths[:100], f'Class: {class_name}')

# %% [markdown]
# #### <span style="color:slateblue">problem 1 </span>: 클래스별 데이터 불균형
# 에폭 수를 늘리면 늘릴수록 차이는 점점 더 벌어 점차 적은 클래스를 무시하는 방향으로 학습됨(점차 가중치 줄어들기 때문)

# %%
#데이터 균형 확인 함수
def show_data_balance(df, label_column='class_name'):
    class_distribution = df[label_column].value_counts()
    print(class_distribution)
    plt.figure(figsize=(10, 6))
    class_distribution.plot(kind='bar')
    plt.title('Class Distribution')
    plt.xlabel('Class')
    plt.ylabel('Number of Images')
    plt.show()

# %%
show_data_balance(train_df)
# Out:
# class_name
# payment_confirmation                                     80
# prescription                                             80
# account_number                                           80
# national_id_card                                         80
# confirmation_of_admission_and_discharge                  80
# medical_bill_receipts                                    80
# diagnosis                                                80
# driver_lisence                                           80
# passport                                                 80
# vehicle_registration_certificate                         80
# pharmaceutical_receipt                                   80
# car_dashboard                                            80
# medical_outpatient_certificate                           80
# vehicle_registration_plate                               80
# resume                                                   59
# statement_of_opinion                                     40
# application_for_payment_of_pregnancy_medical_expenses    37
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Data PreProcessing

# %% [markdown]
# #### 데이터프레임에 존재하지 않는 이미지 파일 행 제거

# %%
# Missing images 제거 함수
def remove_missing_images(df, image_dir):
    available_data = []
    missing_files = []

    for _, row in df.iterrows():
        img_id = row['ID']
        img_path = os.path.join(image_dir, img_id)
        if os.path.exists(img_path):
            available_data.append(row)
        else:
            missing_files.append(img_id)

    # 누락된 파일 로그 출력
    if missing_files:
        print(f"Warning: {len(missing_files)} images not found and will be removed from the dataset.")
        print(f"Missing files: {missing_files}")

    # 누락된 파일을 제외한 DataFrame 반환
    return pd.DataFrame(available_data)

# %%
train_df = remove_missing_images(train_df, image_dir)
val_df = remove_missing_images(val_df, image_dir)

# %% [markdown]
# #### <span style="color:slateblue">solution 1 </span> [트레이닝 데이터셋 클래스별 데이터 불균형 해소] : oversampling - 수치형 데이터에 적합

# %% [raw]
# target_samples_num = {
#     'resume' : 100,
#     'statement_of_opinion' : 100,
#     'application_for_payment_of_pregnancy_medical_expenses': 100
# }
#
# #sampling strategy : 기존 샘플 수보다 클 때만 증강
# sampling_strategy = {}
# for class_name, count in target_samples_num.items():
#     if class_distribution[class_name] < count :
#         sampling_strategy[class_name] = count
#
# #문자열 열 제외 -  SMOTE는 수치형 데이터에 적합하기 때문
#
# X = train_df.drop(columns=['class_name', 'ID'])
# y = train_df['class_name']
#
# #클래스별 분포
# class_distribution = train_df['class_name'].value_counts()
#
# #SMOTE로 증강
# smote = SMOTE(sampling_strategy = sampling_strategy, random_state=42)
# X_resampled, y_resampled = smote.fit_resample(X, y)
#
# #오버샘플링된 데이터와 결합하여 데이터셋 생성
# train_df = pd.concat([X_resampled, y_resampled], axis=1)
# print(train_df['class_name'].value_counts())

# %% [markdown]
# #### <span style="color:slateblue">solution 1 </span> [트레이닝 데이터셋 클래스별 데이터 불균형 해소] : Albumentations

# %%
#증강 파이프라인 설정
augmentation_pipeline = A.Compose([
    A.Resize(128, 128),  # 크기 조정 추가
    A.RandomRotate90(p=0.5),
    A.Flip(p=0.5),
    A.Transpose(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=45, p=0.5),
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.Blur(blur_limit=3, p=0.1),
    ToTensorV2()
])

# 기본 변환 설정 (검증 또는 테스트 데이터에 사용)
basic_transform = A.Compose([
    A.Resize(128, 128),
    ToTensorV2()
])

# %%
#Augmentation - Albumentation
def get_albumentations_pipeline():
    return A.Compose([
        A.Resize(128, 128),
        A.OneOf([
            A.Transpose(p=0.3),
            A.HorizontalFlip(p=0.3),
            A.VerticalFlip(p=0.3)
        ], p=0.5),
        A.OneOf([
            A.Blur(blur_limit=3, p=0.3),
            A.GaussNoise(var_limit=(10.0, 50.0), p=0.3),
            A.ISONoise(color_shift=(0.01, 0.05), intensity=(0.1, 0.5), p=0.3)
        ], p=0.5),
        A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
        ToTensorV2()
    ])

# %%
# Augraphy
def get_augraphy_augmentations():
    return aug.Compose([
        aug.OneOf([
            aug.InkBleed(intensity_range=(0.1, 0.3), p=0.5)
        ], p=0.5),
        aug.OneOf([
            aug.LightingGradient(lightness_range=(0.5, 1.0), p=0.5),
            aug.LowLightNoise(p=0.3)
        ], p=0.5),
        aug.OneOf([
            aug.ReflectedLight(p=0.4),
            aug.ShadowCast(shadow_intensity_range=(0.3, 0.6), p=0.4)
        ], p=0.5)
    ])

# %%
# mixup 함수 - 크기와 채널을 일관되게 처리
def mixup(image1, image2, alpha=0.4):
    # 이미지가 numpy 배열인지 확인하고 변환
    if not isinstance(image1, np.ndarray):
        image1 = np.array(image1)
    if not isinstance(image2, np.ndarray):
        image2 = np.array(image2)
        
    # 두 이미지 크기를 일치시킴
    if image1.shape[:2] != image2.shape[:2]:
        image2 = cv2.resize(image2, (image1.shape[1], image1.shape[0]))

    # 두 이미지를 강제로 3채널로 변환하여 일관성 유지
    if len(image1.shape) == 2:
        image1 = cv2.cvtColor(image1, cv2.COLOR_GRAY2BGR)
    if len(image2.shape) == 2:
        image2 = cv2.cvtColor(image2, cv2.COLOR_GRAY2BGR)
    
    return cv2.addWeighted(image1, alpha, image2, 1 - alpha, 0)

# %%
# balance_classes 함수 - 증강 이미지를 저장하고 데이터프레임에 추가
def balance_classes(df, image_dir, target_count=100):
    balanced_data = []
    augmentation_pipeline = get_albumentations_pipeline()
    
    if not os.path.exists(image_dir):
        os.makedirs(image_dir)
    
    for cls in df['class_name'].unique():
        class_data = df[df['class_name'] == cls]
        n_samples = max(target_count, len(class_data))
        
        for _ in range(n_samples - len(class_data)):
            sample = class_data.sample(1, replace=True).iloc[0]
            image_path = os.path.join(image_dir, sample['ID'])
            
            if os.path.exists(image_path):
                # Load and augment the original image
                image = np.array(Image.open(image_path))
                augmented_image = augmentation_pipeline(image=image)['image'].permute(1, 2, 0).numpy()
                
                # Save augmented image with a unique name
                aug_img_name = f"aug_{np.random.randint(100000)}.jpg"
                aug_img_path = os.path.join(image_dir, aug_img_name)
                
                Image.fromarray(augmented_image.astype(np.uint8)).save(aug_img_path)
                
                # Add the augmented image to the DataFrame
                new_sample = sample.to_dict()
                new_sample['ID'] = aug_img_name
                balanced_data.append(new_sample)

        balanced_data.extend(class_data.to_dict('records'))
    
    balanced_df = pd.DataFrame(balanced_data)
    return balanced_df

# %%
train_df = balance_classes(train_df, image_dir)

# %% [markdown]
# ## 4. Define Functions

# %%
# epoch 학습을 위한 함수

# %% [markdown]
# ## 5. Hyper Parameters

# %%
class DocumentDataset(Dataset):
    def __init__(self, df, image_dir, transform=None, mixup_prob=0.5):
        self.df = df[['ID', 'class_name']].values
        self.image_dir = image_dir
        self.transform = transform
        self.mixup_prob = mixup_prob

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_id, target = self.df[idx]
        img_path = os.path.join(self.image_dir, img_id)

        if not os.path.exists(img_path):
            raise FileNotFoundError(f"Image {img_id} not found in {self.image_dir}.")

        image = np.array(Image.open(img_path))
        
        if self.transform:
            transformed = self.transform(image=image)
            image = transformed['image']
            if isinstance(image, torch.Tensor):
                image = image.permute(1, 2, 0).numpy()

        #Mixup 과정
        if np.random.rand() < self.mixup_prob:
            idx2 = np.random.randint(0, len(self.df))
            img_id2, _ = self.df[idx2]
            img_path2 = os.path.join(self.image_dir, img_id2)

            if os.path.exists(img_path2):
                image2 = np.array(Image.open(img_path2))

                # Resize the second image to match the first image's shape
                if image.shape != image2.shape:
                    image2 = cv2.resize(image2, (image.shape[1], image.shape[0]))

                # Perform mixup with adjusted sizes
                image = cv2.addWeighted(image, 0.5, image2, 0.5, 0)

        # Convert image to torch.Tensor if it’s not already
        if isinstance(image, np.ndarray):
            image = torch.tensor(image, dtype=torch.float32).permute(2, 0, 1)  # Convert to C x H x W format

        #target = torch.tensor(self.df[idx, 1])
        return image, target

# %% [markdown]
# ## 6. Load Data

# %% [raw]
# class DocumentDataset(Dataset):
#     def __init__(self, df, image_dir, transform=None, mixup_prob=0.5):
#         self.df = df[['ID', 'class_name']].values  # Only include necessary columns
#         self.image_dir = image_dir
#         self.transform = transform
#         self.mixup_prob = mixup_prob
#
#     def __len__(self):
#         return len(self.df)
#
#     def __getitem__(self, idx):
#         img_id, target = self.df[idx]  # Ensure we only retrieve ID and class_name
#         img_path = os.path.join(self.image_dir, img_id)
#         image = np.array(Image.open(img_path))
#
#         if self.transform:
#             image = self.transform(image=image)['image']
#         if random.random() < self.mixup_prob:
#             idx2 = random.randint(0, len(self.df) - 1)
#             img_id2, target2 = self.df[idx2]
#             img_path2 = os.path.join(self.image_dir, img_id2)
#             image2 = np.array(Image.open(img_path2))
#             image = mixup(image, image2)
#
#         return image, target

# %% [markdown]
# ## 7. Modeling

# %%
# Model selection function
def get_model(model_type="efficientnet_b0", num_classes=10):
    if model_type in ["resnet18", "resnet50", "efficientnet_b0", "vit_base_patch16_224"]:
        model = create_model(model_type, pretrained=True, num_classes=num_classes)
    else:
        raise ValueError("Unsupported model type. Choose from 'resnet18', 'resnet50', 'efficientnet_b0', or 'vit_base_patch16_224'.")
    return model

# %% [markdown]
# ## 8. Train Model

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for batch in loader:
        print(batch)  # 데이터 구조 확인
        images, labels = batch  # 구조가 맞는지 확인하고 필요한 경우 수정
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * images.size(0)
    return total_loss / len(loader.dataset)

# %% [markdown]
# ## 9. Result

# %%
def evaluate(model, loader, device):
    model.eval()
    preds, true_labels = [], []
    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            outputs = model(images)
            preds.extend(torch.argmax(outputs, axis=1).cpu().numpy())
            true_labels.extend(labels.cpu().numpy())
    return f1_score(true_labels, preds, average='macro')

# %% [raw]
# # DataLoader 준비 함수
# def prepare_dataloader(df, img_dir, batch_size=32, augment=False, target_count=100):
#     train_df = balance_classes(df, target_count)  # 데이터 불균형 해소
#     show_data_balance(train_df)
#     transform = augmentation_pipeline if augment else basic_transform #증강 여부 설정
#     dataset = ImageDataset(train_df, img_dir, transform=transform)
#     return DataLoader(dataset, batch_size=batch_size, shuffle=augment)
#
# # DataLoader 생성 (훈련 시에는 실시간 증강 적용)
# train_loader = prepare_dataloader(train_df, img_dir, batch_size=32, augment=True, target_count=100)

# %%
# Prepare DataLoaders
train_transform = get_albumentations_pipeline()
train_dataset = DocumentDataset(train_df, image_dir, transform=train_transform)
val_dataset = DocumentDataset(val_df, image_dir, transform=train_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Training loop
device = "cuda" if torch.cuda.is_available() else "cpu"
model = get_model(model_type="resnet50", num_classes=len(train_df["class_name"].unique())).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=0.001)

images, labels = next(iter(train_loader))
print("Batch structure:", images, labels)
# Out:
# Batch structure: tensor([[[[161., 163., 146.,  ..., 154., 154., 153.],
#           [177., 180., 152.,  ..., 153., 152., 152.],
#           [184., 186., 150.,  ..., 152., 152., 152.],
#           ...,
#           [184., 184., 185.,  ..., 162., 162., 161.],
#           [174., 177., 178.,  ..., 153., 152., 152.],
#           [175., 183., 188.,  ..., 158., 158., 162.]],
#
#          [[162., 165., 148.,  ..., 152., 152., 152.],
#           [178., 182., 154.,  ..., 152., 151., 150.],
#           [186., 188., 152.,  ..., 151., 150., 150.],
#           ...,
#           [185., 185., 186.,  ..., 168., 168., 167.],
#           [176., 178., 178.,  ..., 159., 158., 158.],
#           [176., 184., 188.,  ..., 163., 164., 167.]],
#
#          [[160., 164., 148.,  ..., 155., 154., 154.],
#           [176., 180., 152.,  ..., 154., 154., 153.],
#           [184., 188., 152.,  ..., 154., 153., 152.],
#           ...,
#           [186., 185., 185.,  ..., 174., 175., 174.],
#           [176., 178., 178.,  ..., 166., 165., 166.],
#           [177., 184., 188.,  ..., 172., 171., 174.]]],
#
#
#         [[[104., 109., 111.,  ..., 126., 124., 120.],
#           [110., 112., 114.,  ..., 124., 123., 120.],
#           [113., 114., 112.,  ..., 123., 122., 120.],
#           ...,
#           [130., 132., 134.,  ..., 133., 133., 132.],
#           [128., 128., 132.,  ..., 134., 134., 136.],
#           [133., 130., 130.,  ..., 127., 128., 131.]],
#
#          [[128., 132., 136.,  ..., 154., 151., 147.],
#           [133., 136., 138.,  ..., 152., 150., 147.],
#           [136., 137., 136.,  ..., 150., 150., 146.],
#           ...,
#           [153., 156., 158.,  ..., 155., 156., 154.],
#           [152., 152., 155.,  ..., 156., 156., 158.],
#           [156., 154., 153.,  ..., 150., 150., 152.]],
#
#          [[140., 144., 148.,  ..., 168., 166., 161.],
#           [146., 148., 150.,  ..., 166., 164., 161.],
#           [148., 150., 148.,  ..., 165., 164., 162.],
#           ...,
#           [167., 171., 173.,  ..., 170., 169., 168.],
#           [166., 166., 170.,  ..., 169., 170., 171.],
#           [171., 168., 168.,  ..., 163., 163., 165.]]],
#
#
#         [[[ 56.,  55.,  44.,  ...,  31.,  34.,  36.],
#           [ 52.,  54.,  51.,  ...,  35.,  37.,  38.],
#           [ 69.,  47.,  48.,  ...,  37.,  37.,  37.],
#           ...,
#           [ 15.,  16.,  16.,  ...,  14.,  16.,  18.],
#           [ 15.,  15.,  14.,  ...,  17.,  16.,  15.],
#           [ 17.,  16.,  15.,  ...,  19.,  17.,  16.]],
#
#          [[ 63.,  64.,  57.,  ...,  43.,  45.,  48.],
#           [ 56.,  60.,  60.,  ...,  47.,  49.,  49.],
#           [ 71.,  51.,  53.,  ...,  49.,  49.,  49.],
#
#          [[162., 164., 168.,  ..., 160., 152., 158.],
#           [165., 168., 166.,  ..., 156., 159., 162.],
#           [165., 170., 164.,  ..., 158., 159., 157.],
#           ...,
#           [225., 227., 229.,  ..., 225., 223., 224.],
#           [228., 227., 225.,  ..., 226., 223., 220.],
#           [224., 222., 226.,  ..., 225., 228., 223.]],
#
#          [[173., 176., 174.,  ..., 166., 166., 164.],
#           [174., 177., 174.,  ..., 166., 167., 167.],
#           [175., 176., 175.,  ..., 171., 168., 166.],
#           ...,
#           [210., 209., 208.,  ..., 207., 206., 203.],
#           [210., 210., 210.,  ..., 207., 205., 204.],
#           [209., 208., 208.,  ..., 205., 205., 204.]]]]) ('national_id_card', 'payment_confirmation', 'national_id_card', 'resume', 'pharmaceutical_receipt', 'driver_lisence', 'driver_lisence', 'payment_confirmation', 'prescription', 'vehicle_registration_certificate', 'medical_bill_receipts', 'confirmation_of_admission_and_discharge', 'vehicle_registration_plate', 'prescription', 'driver_lisence', 'driver_lisence', 'diagnosis', 'payment_confirmation', 'pharmaceutical_receipt', 'application_for_payment_of_pregnancy_medical_expenses', 'car_dashboard', 'prescription', 'medical_bill_receipts', 'resume', 'confirmation_of_admission_and_discharge', 'driver_lisence', 'vehicle_registration_certificate', 'medical_bill_receipts', 'car_dashboard', 'application_for_payment_of_pregnancy_medical_expenses', 'account_number', 'resume')

# %%
for epoch in range(10):
    train_loss = train_epoch(model, train_loader, optimizer, criterion, device)
    val_f1 = evaluate(model, val_loader, device)
    print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Val Macro F1: {val_f1:.4f}")
# Out:
# [tensor([[[[117., 116., 120.,  ..., 102., 112., 111.],
#           [119., 119., 126.,  ..., 108., 117., 116.],
#           [124., 132., 127.,  ..., 108., 114., 115.],
#           ...,
#           [ 90.,  92.,  94.,  ..., 106.,  98.,  98.],
#           [ 92.,  97.,  96.,  ...,  94.,  98., 100.],
#           [ 98.,  96.,  92.,  ...,  93.,  93.,  93.]],
#
#          [[120., 118., 121.,  ..., 102., 111., 110.],
#           [120., 118., 126.,  ..., 108., 117., 116.],
#           [124., 130., 124.,  ..., 109., 116., 116.],
#           ...,
#           [100., 102., 104.,  ..., 120., 111., 114.],
#           [102., 107., 106.,  ..., 108., 111., 116.],
#           [108., 106., 102.,  ..., 106., 106., 108.]],
#
#          [[116., 114., 118.,  ..., 103., 113., 112.],
#           [115., 114., 124.,  ..., 108., 117., 116.],
#           [120., 126., 122.,  ..., 108., 114., 115.],
#           ...,
#           [106., 110., 110.,  ..., 134., 122., 124.],
#           [108., 112., 112.,  ..., 120., 122., 125.],
#           [113., 112., 108.,  ..., 116., 117., 117.]]],
#
#
#         [[[168., 170., 165.,  ..., 162., 161., 163.],
#           [154., 152., 144.,  ..., 167., 169., 170.],
#           [164., 157., 144.,  ..., 166., 166., 167.],
#           ...,
#           [148., 136., 140.,  ..., 106., 108., 113.],
#           [125., 116., 144.,  ..., 110., 108., 113.],
#           [ 88.,  74., 126.,  ..., 118., 115., 117.]],
#
#          [[172., 175., 170.,  ..., 163., 160., 163.],
#           [158., 156., 148.,  ..., 167., 169., 170.],
#
#          [[ 50.,  32.,  35.,  ..., 179., 165., 175.],
#           [192.,  44.,  86.,  ..., 168., 152., 162.],
#           [122., 149., 127.,  ..., 177., 164., 179.],
#           ...,
#           [153., 153., 154.,  ..., 140., 159., 158.],
#           [150., 151., 153.,  ..., 131., 148., 139.],
#           [147., 148., 149.,  ..., 144., 158., 140.]],
#
#          [[ 30.,  10.,  12.,  ..., 189., 175., 185.],
#           [169.,  19.,  60.,  ..., 178., 162., 172.],
#           [ 95., 120.,  97.,  ..., 187., 174., 189.],
#           ...,
#           [ 46.,  45.,  46.,  ..., 149., 168., 167.],
#           [ 32.,  31.,  33.,  ..., 140., 157., 148.],
#           [ 44.,  44.,  45.,  ..., 153., 167., 149.]]],
#
#
#         [[[153., 152., 159.,  ..., 122., 143., 140.],
#           [157., 154., 160.,  ..., 127., 142., 144.],
#           [163., 156., 160.,  ..., 129., 130., 140.],
#           ...,
#           [153., 122., 110.,  ..., 121., 131., 141.],
#           [157., 138., 136.,  ..., 152., 162., 167.],
#           [146., 155., 151.,  ..., 166., 162., 149.]],
#
#          [[157., 156., 163.,  ..., 124., 145., 142.],
#           [161., 158., 164.,  ..., 129., 144., 146.],
#           [167., 160., 164.,  ..., 131., 132., 142.],
#           ...,
#           [154., 123., 111.,  ..., 122., 132., 142.],
#           [158., 139., 137.,  ..., 153., 163., 168.],
#           [147., 156., 152.,  ..., 167., 163., 150.]],
#
#          [[158., 157., 164.,  ..., 123., 144., 141.],
#           [162., 159., 165.,  ..., 128., 143., 145.],
#           [168., 161., 165.,  ..., 130., 131., 141.],
#           ...,
#           [159., 128., 116.,  ..., 126., 136., 146.],
#           [163., 144., 142.,  ..., 157., 167., 172.],
#           [152., 161., 157.,  ..., 171., 167., 154.]]]]), ('statement_of_opinion', 'passport', 'confirmation_of_admission_and_discharge', 'vehicle_registration_certificate', 'resume', 'national_id_card', 'medical_bill_receipts', 'car_dashboard', 'vehicle_registration_certificate', 'car_dashboard', 'medical_bill_receipts', 'resume', 'vehicle_registration_plate', 'national_id_card', 'prescription', 'payment_confirmation', 'prescription', 'vehicle_registration_certificate', 'confirmation_of_admission_and_discharge', 'confirmation_of_admission_and_discharge', 'car_dashboard', 'driver_lisence', 'prescription', 'national_id_card', 'confirmation_of_admission_and_discharge', 'medical_outpatient_certificate', 'diagnosis', 'application_for_payment_of_pregnancy_medical_expenses', 'medical_bill_receipts', 'confirmation_of_admission_and_discharge', 'vehicle_registration_plate', 'payment_confirmation')]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 for epoch in range(10):
# ----> 2     train_loss = train_epoch(model, train_loader, optimizer, criterion, device)
#       3     val_f1 = evaluate(model, val_loader, device)
#       4     print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Val Macro F1: {val_f1:.4f}")
#
# Cell In[42], line 7, in train_epoch(model, loader, optimizer, criterion, device)
#       5 print(batch)  # 데이터 구조 확인
#       6 images, labels = batch  # 구조가 맞는지 확인하고 필요한 경우 수정
# ----> 7 images, labels = images.to(device), labels.to(device)
#       8 optimizer.zero_grad()
#       9 outputs = model(images)
#
# AttributeError: 'tuple' object has no attribute 'to'

# %% [markdown]
# ## 9. Save File
